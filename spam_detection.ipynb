# %% [markdown]
# <a href="https://colab.research.google.com/github/aparnasankar2004-cmyk/Project-on-Spam_Detection/blob/main/spam_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/spam.csv",encoding="ISO-8859-1",nrows=2000)
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (2000, 5)

# %%
x=df.iloc[:,1]
x
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 1995                           Shall i come to get pickle
# 1996                     Lol boo I was hoping for a laugh
# 1997                      \YEH I AM DEF UP4 SOMETHING SAT
# 1998    Well, I have to leave for my class babe ... Yo...
# 1999        LMAO where's your fish memory when I need it?
# Name: v2, Length: 2000, dtype: object

# %%
y=df.iloc[:,0]
y
# Out:
# 0        ham
# 1        ham
# 2       spam
# 3        ham
# 4        ham
#         ...
# 1995     ham
# 1996     ham
# 1997     ham
# 1998     ham
# 1999     ham
# Name: v1, Length: 2000, dtype: object

# %%
import re
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import TweetTokenizer
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('wordnet')
sw = stopwords.words('english')
tk = TweetTokenizer()
le=WordNetLemmatizer()
def preprocess_text(text):
    if not isinstance(text, str):
        return ""
    text = re.sub("[^0-9a-zA-Z]+", " ", text)
    tokens = tk.tokenize(text)
    tokens = [le.lemmatize(i.lower()) for i in tokens]
    tokens = [i for i in tokens if i not in sw]
    return " ".join(tokens)
tweets= df['v2'].apply(preprocess_text)
print("First 10 cleaned tweets:\n")
print(tweets.head(10))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# First 10 cleaned tweets:
#
# 0    go jurong point crazy available bugis n great ...
# 1                              ok lar joking wif u oni
# 2    free entry 2 wkly comp win fa cup final tkts 2...
# 3                  u dun say early hor u c already say
# 4                  nah think go usf life around though
# 5    freemsg hey darling 3 week word back like fun ...
# 6        even brother like speak treat like aid patent
# 7    per request melle melle oru minnaminunginte nu...
# 8    winner valued network customer selected receiv...
# 9    mobile 11 month u r entitled update latest col...
# Name: v2, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf=TfidfVectorizer()
x=tf.fit_transform(tweets)
print(x)
print(tf.get_feature_names_out())
print(x.toarray())
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 17231 stored elements and shape (2000, 4530)>
#   Coords	Values
#   (0, 1938)	0.16301326060211746
#   (0, 2347)	0.3289260740032221
#   (0, 3123)	0.2424363832809975
#   (0, 1267)	0.2908150233086129
#   (0, 746)	0.2663673599148327
#   (0, 972)	0.30009617709581393
#   (0, 1980)	0.20329829894141282
#   (0, 4449)	0.2352886586279089
#   (0, 2406)	0.30009617709581393
#   (0, 971)	0.3120616654127315
#   (0, 1123)	0.30009617709581393
#   (0, 1960)	0.1705965154054071
#   (0, 629)	0.3289260740032221
#   (0, 4337)	0.2222427784171358
#   (1, 2927)	0.273101772212823
#   (1, 2422)	0.40260369837673915
#   (1, 2329)	0.5289152246811835
#   (1, 4398)	0.4514676669136931
#   (1, 2941)	0.5289152246811835
#   (2, 1831)	0.12370713911455213
#   (2, 1608)	0.35471449438937636
#   (2, 4432)	0.1905001030004765
#   (2, 1178)	0.20798453651412183
#   (2, 4407)	0.15096332803011883
#   (2, 1682)	0.44635933939228295
#   :	:
# ...

# %%
#from sklearn.cluster import KMeans
#km=KMeans(n_clusters=5,init="k-means++",random_state=42)
#km.fit(x)

# %%
#y_predict=km.predict(x)
#y_predict

# %%
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
clf=Pipeline([("tfidf",TfidfVectorizer()),("naive_bayes",MultinomialNB())])
clf.fit(tweets,df.iloc[:,0])
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('naive_bayes', MultinomialNB())])

# %%
new=clf.predict(["U dun say so early hor... U c already then say...	"])
new
# Out:
# array(['ham'], dtype='<U4')

# %%
new=clf.predict(["WINNER!! As a valued network customer you have been selected to receivea �900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.	"])
new
# Out:
# array(['spam'], dtype='<U4')
